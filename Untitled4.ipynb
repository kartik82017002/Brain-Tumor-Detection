# %%
from google.colab import drive
drive.mount('/content/drive')
import os

project_path = "/content/drive/MyDrive/Brain_Tumor_Project"

os.makedirs(project_path, exist_ok=True)

print(project_path)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Brain_Tumor_Project

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input

from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
train_path = "/content/drive/MyDrive/Brain_Tumor_Project/dataset/Training"
test_path = "/content/drive/MyDrive/Brain_Tumor_Project/dataset/Testing"

# %%
IMG_SIZE = (224,224)
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)

validation_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# %%
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="training"
)

validation_generator = validation_datagen.flow_from_directory(
    train_path,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation"
)

test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 4491 images belonging to 4 classes.
# Found 1121 images belonging to 4 classes.
# Found 1626 images belonging to 4 classes.

# %%
base_model = ResNet50(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

base_model.trainable=False
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)

x = Dense(256,activation="relu")(x)

x = Dropout(0.5)(x)

output = Dense(4,activation="softmax")(x)

model = Model(
    inputs=base_model.input,
    outputs=output
)

# %%
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
EPOCHS = 10

checkpoint_path="/content/drive/MyDrive/Brain_Tumor_Project/models/best_brain_tumor_model.keras"

early_stopping=EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True
)

model_checkpoint=ModelCheckpoint(
    checkpoint_path,
    monitor="val_accuracy",
    save_best_only=True,
    mode="max"
)

# %%
history=model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=EPOCHS,
    callbacks=[
        early_stopping,
        model_checkpoint
    ]
)
# Out:
# Epoch 1/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1346s 9s/step - accuracy: 0.7820 - loss: 0.5998 - val_accuracy: 0.8680 - val_loss: 0.3427
# Epoch 2/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1121s 8s/step - accuracy: 0.8568 - loss: 0.3703 - val_accuracy: 0.9028 - val_loss: 0.2714
# Epoch 3/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1112s 8s/step - accuracy: 0.8778 - loss: 0.3200 - val_accuracy: 0.8992 - val_loss: 0.2545
# Epoch 4/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1105s 8s/step - accuracy: 0.8795 - loss: 0.3142 - val_accuracy: 0.8956 - val_loss: 0.2582
# Epoch 5/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1096s 8s/step - accuracy: 0.8929 - loss: 0.2873 - val_accuracy: 0.9099 - val_loss: 0.2217
# Epoch 6/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1102s 8s/step - accuracy: 0.8936 - loss: 0.2778 - val_accuracy: 0.9045 - val_loss: 0.2373
# Epoch 7/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1093s 8s/step - accuracy: 0.8933 - loss: 0.2758 - val_accuracy: 0.9010 - val_loss: 0.2582
# Epoch 8/10
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history["accuracy"],label="Training Accuracy")
plt.plot(history.history["val_accuracy"],label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy Graph")
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1481/438435459.py in <cell line: 0>()
#       1 plt.figure(figsize=(8,5))
# ----> 2 plt.plot(history.history["accuracy"],label="Training Accuracy")
#       3 plt.plot(history.history["val_accuracy"],label="Validation Accuracy")
#       4
#       5 plt.xlabel("Epoch")
#
# NameError: name 'history' is not defined

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history["loss"],label="Training Loss")
plt.plot(history.history["val_loss"],label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Graph")
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1481/1926055492.py in <cell line: 0>()
#       1 plt.figure(figsize=(8,5))
#       2
# ----> 3 plt.plot(history.history["loss"],label="Training Loss")
#       4 plt.plot(history.history["val_loss"],label="Validation Loss")
#       5
#
# NameError: name 'history' is not defined

# %%
test_loss,test_accuracy=model.evaluate(test_generator)

print("Test Loss :",test_loss)
print("Test Accuracy :",test_accuracy)
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 184s 4s/step - accuracy: 0.2300 - loss: 1.6130
# Test Loss : 1.6129707098007202
# Test Accuracy : 0.23001229763031006

# %%
model.save("/content/drive/MyDrive/Brain_Tumor_Project/models/final_brain_tumor_model.keras")

print("Model Saved Successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1481/1193679997.py in <cell line: 0>()
# ----> 1 model.save("/content/drive/MyDrive/Brain_Tumor_Project/models/final_brain_tumor_model.keras")
#       2
#       3 print("Model Saved Successfully")
#
# NameError: name 'model' is not defined

# %%
from tensorflow.keras.models import load_model
import os

model_path = "/content/drive/MyDrive/Brain_Tumor_Project/models/final_brain_tumor_model.keras"

model = load_model(model_path)

print("Model Loaded Successfully!")
# Out:
# Model Loaded Successfully!
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
from google.colab import files

uploaded = files.upload()

print("Image Uploaded Successfully!")
# Out:
#      <input type="file" id="files-9cd2674c-32dd-4b2e-ae8e-3bff688da55c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9cd2674c-32dd-4b2e-ae8e-3bff688da55c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np
import matplotlib.pyplot as plt

image_path = list(uploaded.keys())[0]

image = load_img(image_path, target_size=(224, 224))

image_array = img_to_array(image)

image_array = np.expand_dims(image_array, axis=0)

image_array = preprocess_input(image_array)

print("Image Prepared Successfully!")
print("Image Shape:", image_array.shape)
# Out:
# Image Prepared Successfully!
# Image Shape: (1, 224, 224, 3)

# %%
prediction = model.predict(image_array)

print("Prediction Probabilities:")
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1481/2166982401.py in <cell line: 0>()
# ----> 1 prediction = model.predict(image_array)
#       2
#       3 print("Prediction Probabilities:")
#       4 print(prediction)
#
# NameError: name 'model' is not defined

# %%
class_names = ['glioma', 'meningioma', 'notumor', 'pituitary']

predicted_index = np.argmax(prediction)
predicted_class = class_names[predicted_index]
confidence = prediction[0][predicted_index] * 100

print("Predicted Class:", predicted_class)
print("Confidence: {:.2f}%".format(confidence))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1481/3455572485.py in <cell line: 0>()
#       1 class_names = ['glioma', 'meningioma', 'notumor', 'pituitary']
#       2
# ----> 3 predicted_index = np.argmax(prediction)
#       4 predicted_class = class_names[predicted_index]
#       5 confidence = prediction[0][predicted_index] * 100
#
# NameError: name 'np' is not defined

# %%
plt.figure(figsize=(6, 6))

plt.imshow(load_img(image_path))

plt.title(
    f"Prediction: {predicted_class}\n"
    f"Confidence: {confidence:.2f}%"
)

plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1481/1236764030.py in <cell line: 0>()
# ----> 1 plt.figure(figsize=(6, 6))
#       2
#       3 plt.imshow(load_img(image_path))
#       4
#       5 plt.title(
#
# NameError: name 'plt' is not defined

# %%
# !pip install flask

# %%
import os

flask_path = "/content/drive/MyDrive/Brain_Tumor_Project/flask_app"

os.makedirs(flask_path, exist_ok=True)
os.makedirs(os.path.join(flask_path, "templates"), exist_ok=True)
os.makedirs(os.path.join(flask_path, "static"), exist_ok=True)

print("Flask folders created successfully!")
# Out:
# Flask folders created successfully!

# %%
model.save(
    "/content/drive/MyDrive/Brain_Tumor_Project/flask_app/brain_tumor_model.keras"
)

print("Model copied to Flask app successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1462/3299897108.py in <cell line: 0>()
# ----> 1 model.save(
#       2     "/content/drive/MyDrive/Brain_Tumor_Project/flask_app/brain_tumor_model.keras"
#       3 )
#       4
#       5 print("Model copied to Flask app successfully!")
#
# NameError: name 'model' is not defined

# %%
"""
<!DOCTYPE html>
<html>
<head>
    <title>Brain Tumor Detection</title>

    <style>
        body {
            font-family: Arial, sans-serif;
            text-align: center;
            background: #f2f2f2;
            padding: 50px;
        }

        .container {
            background: white;
            max-width: 600px;
            margin: auto;
            padding: 40px;
            border-radius: 15px;
        }

        h1 {
            color: #222;
        }

        #preview {
            display: none;
            width: 300px;
            max-height: 300px;
            object-fit: contain;
            margin: 20px auto;
            border-radius: 10px;
        }

        input {
            margin: 20px;
        }

        button {
            padding: 12px 25px;
            border: none;
            border-radius: 8px;
            background: #333;
            color: white;
            cursor: pointer;
        }

        button:hover {
            background: #555;
        }
    </style>
</head>

<body>

<div class="container">

    <h1>🧠 Brain Tumor Detection</h1>

    <p>Upload an MRI image to get a model prediction.</p>

    <form action="/predict" method="POST" enctype="multipart/form-data">

        <input
            type="file"
            name="image"
            accept="image/*"
            onchange="showPreview(event)"
            required
        >

        <br>

        <img id="preview">

        <br>

        <button type="submit">Predict</button>

    </form>

</div>

<script>
function showPreview(event) {

    const image = document.getElementById("preview");

    image.src = URL.createObjectURL(event.target.files[0]);

    image.style.display = "block";
}
</script>

</body>
</html>
"""

html_path = os.path.join(
    flask_path,
    "templates",
    "index.html"
)

with open(html_path, "w", encoding="utf-8") as f:
    f.write(html_code)

print("Website updated successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1462/3491279092.py in <cell line: 0>()
#     105
#     106 with open(html_path, "w", encoding="utf-8") as f:
# --> 107     f.write(html_code)
#     108
#     109 print("Website updated successfully!")
#
# NameError: name 'html_code' is not defined

# %%
app_code = '''
from flask import Flask, render_template, request
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np
import os

app = Flask(__name__)

model_path = os.path.join(
    os.path.dirname(__file__),
    "brain_tumor_model.keras"
)

model = load_model(model_path)

class_names = [
    "glioma",
    "meningioma",
    "notumor",
    "pituitary"
]

@app.route("/")
def home():
    return render_template("index.html")

@app.route("/predict", methods=["POST"])
def predict():

    if "image" not in request.files:
        return "No image uploaded"

    file = request.files["image"]

    if file.filename == "":
        return "No image selected"

    image_path = os.path.join(
        os.path.dirname(__file__),
        "uploaded_image.jpg"
    )

    file.save(image_path)

    image = load_img(
        image_path,
        target_size=(224, 224)
    )

    image_array = img_to_array(image)
    image_array = np.expand_dims(image_array, axis=0)
    image_array = preprocess_input(image_array)

    prediction = model.predict(
        image_array,
        verbose=0
    )

    predicted_index = np.argmax(prediction)
    predicted_class = class_names[predicted_index]
    confidence = float(
        prediction[0][predicted_index] * 100
    )

    result = f"""
    <html>
    <body style="text-align:center; font-family:Arial; padding:50px;">
        <h1>Brain Tumor Detection Result</h1>
        <h2>Prediction: {predicted_class}</h2>
        <h3>Confidence: {confidence:.2f}%</h3>
        <br>
        <a href="/">Upload Another Image</a>
    </body>
    </html>
    """

    return result

if __name__ == "__main__":
    app.run(
        host="0.0.0.0",
        port=5000
    )
'''

app_path = os.path.join(flask_path, "app.py")

with open(app_path, "w", encoding="utf-8") as f:
    f.write(app_code)

print("app.py created successfully!")
# Out:
# app.py created successfully!

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok
ngrok.kill()

print("ngrok ready!")
# Out:
# ngrok ready!

# %%
import subprocess
import time

app_path = "/content/drive/MyDrive/Brain_Tumor_Project/flask_app/app.py"

process = subprocess.Popen(
    ["python", app_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE
)

time.sleep(5)

print("Flask server started!")
# Out:
# Flask server started!

# %%
# !pip install flask flask-cors

# %%
import subprocess
import time

app_path = "/content/drive/MyDrive/Brain_Tumor_Project/flask_app/app.py"

process = subprocess.Popen(
    ["python", app_path],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE
)

time.sleep(3)

print("Flask server started on port 5000")
# Out:
# Flask server started on port 5000

# %%
from google.colab import output

output.serve_kernel_port_as_window(5000)
# Out:
# ...
# Try `serve_kernel_port_as_iframe` instead.

# %%
from google.colab import files

files.download(
    "/content/drive/MyDrive/Brain_Tumor_Project/flask_app/app.py"
)

# %%
from google.colab import files

files.download(
    "/content/drive/MyDrive/Brain_Tumor_Project/flask_app/templates/index.html"
)
